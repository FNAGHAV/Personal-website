# %%
# Define the HTML content for the "Conference and Scientific Contributions" page 
conference_scientific_contributions_html = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Conference and Scientific Contributions</title>
    <link rel="stylesheet" href="style.css">
    <style>
        body {
            font-family: Arial, sans-serif;
            line-height: 1.6;
            padding: 0;
            background-color: #f5f5f5;
            color: #333;
        }
        .title-holder {
            background-image: url('present_1.webp');
            background-position: right;
            background-repeat: no-repeat;
            background-size: contain;
            background-color: #a9a9a9;
            height: 20vh;
            width: 100%;
            user-select: none;
            display: flex;
            justify-content: center;
        }
        h1 {
            color: #333;
            margin-bottom: 40px;
        }
        h1.title {
            text-align: center;
            font-size: 2.5rem;
            padding: 40px;
        }
        .list-holder {
            list-style: none;
            padding: 0;
        }
        .content {
            padding: 40px;
            text-align: justify;
            margin-left: 40px;
            margin-right: 40px;
        }
        .list {
            display: flex;
            align-items: center;
            margin-bottom: 40px;
        }
        .list img {
            width: 50px;
            height: 50px;
            border-radius: 50%; 
            margin-right: 40px;
        }
        .list p {
            margin: 0;
            font-size: 1.2rem; 
            margin-right: 40px;
            color: #333;
        }
        .list p a:hover {
            color: #007bff;
        }
        .desc {
            padding: 20px 40px;
            font-size: 1.2rem; 
            margin-left: 40px;
            margin-right: 40px;
        }
    </style>
</head>
<body>
    <section class="title-holder margin-zero">
        <h1 class="title">Conference and Scientific Contributions</h1>
    </section>
    <section class="content margin-zero">
        <p class="desc">I have had the privilege of participating in numerous scientific events in the field of neuroscience:</p>
        <br>
        <ul class="list-holder"> 
            <li class="list">
                <img src="Utoledo.jpg" alt="Utoledo Logo">
                <p><strong>2023</strong> <br> F. Naghavi, A Dehghan, J Burkett <br> Priming Effect of Past Experience on Consoling Behavior <br> Graduate Research Forum <br>Poster presentation <br> University of Toledo, Ohio 
                </p>
            </li>
            <li class="list">
                <img src="Utoledo.jpg" alt="Utoledo Logo">
                <p><strong>2020</strong> <br> F. Naghavi, J. Burkett <br> Prosocial comforting behavior in mice <br> Graduate Research Forum <br>Poster presentation <br> University of Toledo, Ohio.
                </p>
            </li>
            <li class="list">
                <img src="SfN.jpg" alt="SfN Logo">
                <p><strong>2019</strong> <br> J. Du, B. Lin, F. Naghavi, E. Koffman, C. Kruse, K. Singh <br> AMPA receptor endocytosis enhanced by transient acidification in retrieval-induced lability of an aversive memory <br> Society of Neuroscience (SfN) <br> Poster presentation<br> Chicago, IL
                </p>
            </li>
            <li class="list">
                <img src="SfN.jpg" alt="SfN Logo">
                <p><strong>2019</strong> <br> F. Naghavi, E. Koffman, C. Kruse, B. Lin, J. Du <br> The effect of CO2 on the lability of fear memory <br> Society of Neuroscience (SfN) <br> Poster presentation <br> Chicago, IL
                </p>
            </li>
            <li class="list">
                <img src="BCNC.png" alt="BCNC Logo">
                <p><strong>2016</strong> <br> F. Naghavi, P. Namvar, F. Sadeghzadeh, A. Haghparast <br> Effects of intra-CA1 administration of different doses of D1- and D2- receptor antagonists, on the acquisition of intra-VTA orexin-induced CPP <br> 5th Basic and Clinical Neuroscience Congress <br> Oral presentation <br> Tehran, Iran
                </p>
            </li>
            <li class="list">
                <img src="BCNC.png" alt="BCNC Logo">
                <p><strong>2015</strong> <br> F. Naghavi, F. Ebrahimian, F. Yazdi, F. Sadeghzadeh, Z. Taslimi, A. Haghparast <br> The Effect of different doses of Intra-DG Administration of Orexin-1 Receptor Antagonist (SB334867) on the Forced Swim Stress-Induced Reinstatement of Morphine Seeking in Rats <br> 4th Basic and Clinical Neuroscience Congress <br> Poster presentation <br>Tehran, Iran
                </p>
            </li>
        </ul>
    </section>
</body>
</html>     
"""
# Write the HTML content to a file with UTF-8 encoding
with open('Scientific_Contributions.html', 'w', encoding='utf-8') as file:
    file.write(conference_scientific_contributions_html)

print("Publication HTML file created successfully.")
# Out:
# Publication HTML file created successfully.
